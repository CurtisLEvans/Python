# %%
import pandas as pd
MainDF = pd.read_csv("/Users/curtislevans/Downloads/archive/aug_train.csv")

# %%
dataframe = pd.DataFrame()

# %%
MainDF.head(5)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
MainDF['city'].head(5)
# Out:
# 0    city_103
# 1     city_40
# 2     city_21
# 3    city_115
# 4    city_162
# Name: city, dtype: object

# %%
SecondDF=pd.DataFrame()
SecondDF['FirstName']=['Moez','Calvin',"Michael"]
SecondDF['Age']=[28,30,35]
SecondDF['Edu']=[True,True,False]
SecondDF
# Out:
#   FirstName  Age    Edu
# 0      Moez   28   True
# 1    Calvin   30   True
# 2   Michael   35  False

# %%
New_Student=pd.Series(["Peter",25,False],index=['FirstName','Age','Edu'])
SecondDF=SecondDF.append(New_Student,ignore_index=True)
SecondDF
# Out:
#   FirstName  Age    Edu
# 0      Moez   28   True
# 1    Calvin   30   True
# 2   Michael   35  False
# 3     Peter   25  False
# 4     Peter   25  False

# %%
MainDF.shape
# Out:
# (19158, 14)

# %%
MainDF.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000

# %%
X=MainDF['enrollee_id']
X
# Out:
# 0         8949
# 1        29725
# 2        11561
# 3        33241
# 4          666
#          ...
# 19153     7386
# 19154    31398
# 19155    24576
# 19156     5756
# 19157    23834
# Name: enrollee_id, Length: 19158, dtype: int64

# %%
Y=MainDF.iloc[0:5]
Y.shape
# Out:
# (5, 14)

# %%
ExerciseDF=MainDF[ (MainDF['gender']=='Female') & (MainDF['city_development_index']>0.9) & (MainDF['major_discipline']!='STEM') ]
ExerciseDF.head(10)
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 68          12730   city_16                    0.91  Female
# 92          16869  city_103                    0.92  Female
# 578         12140   city_16                    0.91  Female
# 604         10454  city_103                    0.92  Female
# 671         32619  city_103                    0.92  Female
# 873         12310  city_103                    0.92  Female
# 944         14800   city_16                    0.91  Female
# 948          9499  city_103                    0.92  Female
# 1042        26270  city_103                    0.92  Female
# 1137        28931  city_103                    0.92  Female
#
#           relevent_experience enrolled_university education_level  \
# 68    Has relevent experience       no_enrollment         Masters
# 92     No relevent experience       no_enrollment        Graduate
# 578   Has relevent experience       no_enrollment         Masters
# ...

# %%
X=ExerciseDF.replace("No relevent experience","Zero experience")
X
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 68           12730   city_16                   0.910  Female
# 92           16869  city_103                   0.920  Female
# 578          12140   city_16                   0.910  Female
# 604          10454  city_103                   0.920  Female
# 671          32619  city_103                   0.920  Female
# ...            ...       ...                     ...     ...
# 18897        31705  city_103                   0.920  Female
# 18927        21261  city_103                   0.920  Female
# 18929        18637  city_114                   0.926  Female
# 19070        26153  city_103                   0.920  Female
# 19152        29754  city_103                   0.920  Female
#
#            relevent_experience enrolled_university education_level  \
# 68     Has relevent experience       no_enrollment         Masters
# 92             Zero experience       no_enrollment        Graduate
# ...

# %%
ExerciseDF=ExerciseDF.rename(columns={"enrollee_id":"EmployeeID"})
ExerciseDF
# Out:
#        EmployeeID      city  city_development_index  gender  \
# 68          12730   city_16                   0.910  Female
# 92          16869  city_103                   0.920  Female
# 578         12140   city_16                   0.910  Female
# 604         10454  city_103                   0.920  Female
# 671         32619  city_103                   0.920  Female
# ...           ...       ...                     ...     ...
# 18897       31705  city_103                   0.920  Female
# 18927       21261  city_103                   0.920  Female
# 18929       18637  city_114                   0.926  Female
# 19070       26153  city_103                   0.920  Female
# 19152       29754  city_103                   0.920  Female
#
#            relevent_experience enrolled_university education_level  \
# 68     Has relevent experience       no_enrollment         Masters
# 92      No relevent experience       no_enrollment        Graduate
# ...
